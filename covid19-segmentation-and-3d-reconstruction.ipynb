# %%
# !nvidia-smi
# Out:
# Mon Jul 25 18:00:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # **Preprocessing**
# ---
#
#
# ## Pipeline
#
# ![image.png](attachment:ad51af98-122a-4142-9763-ee454803e225.png)

# %%
# Loading dependencies

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import pandas as pd
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import copy
import catalyst
import wandb

from utils.CLAHE import clahe_enhancer
from utils.cropROI import crop_img, crop_
from utils.visualize import visualize_mask
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout, Dropout2d, UpsamplingNearest2d
from albumentations import Compose,HorizontalFlip,VerticalFlip, Rotate
from albumentations.pytorch import ToTensor
from tqdm.autonotebook import tqdm, trange
from catalyst import dl
from catalyst.contrib.nn import DiceLoss, IoULoss, FocalLossBinary
from catalyst.dl.runner import SupervisedRunner
from torch.nn.functional import interpolate
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
seed = 271
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
wandb.login()
# Out:
# wandb: ERROR Not authenticated.  Copy a key from https://app.wandb.ai/authorize
# API Key:  ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
#20 CT-scans + (lung masks / infection masks / lungs + infections mask)

metadata = pd.read_csv('../input/covid19-ct-scans/metadata.csv')
print(metadata.shape)
metadata.head()
# Out:
# (20, 4)
#                                              ct_scan  \
# 0  ../input/covid19-ct-scans/ct_scans/coronacases...
# 1  ../input/covid19-ct-scans/ct_scans/coronacases...
# 2  ../input/covid19-ct-scans/ct_scans/coronacases...
# 3  ../input/covid19-ct-scans/ct_scans/coronacases...
# 4  ../input/covid19-ct-scans/ct_scans/coronacases...
#
#                                            lung_mask  \
# 0  ../input/covid19-ct-scans/lung_mask/coronacase...
# 1  ../input/covid19-ct-scans/lung_mask/coronacase...
# 2  ../input/covid19-ct-scans/lung_mask/coronacase...
# 3  ../input/covid19-ct-scans/lung_mask/coronacase...
# 4  ../input/covid19-ct-scans/lung_mask/coronacase...
#
#                                       infection_mask  \
# 0  ../input/covid19-ct-scans/infection_mask/coron...
# 1  ../input/covid19-ct-scans/infection_mask/coron...
# 2  ../input/covid19-ct-scans/infection_mask/coron...
# 3  ../input/covid19-ct-scans/infection_mask/coron...
# 4  ../input/covid19-ct-scans/infection_mask/coron...
#
#                              lung_and_infection_mask
# 0  ../input/covid19-ct-scans/lung_and_infection_m...
# 1  ../input/covid19-ct-scans/lung_and_infection_m...
# 2  ../input/covid19-ct-scans/lung_and_infection_m...
# 3  ../input/covid19-ct-scans/lung_and_infection_m...
# 4  ../input/covid19-ct-scans/lung_and_infection_m...

# %% [markdown]
# ## **1) CLAHE**

# %%
img_size = 256
clahe = cv2.createCLAHE(clipLimit=3.0)


cts = nib.load(metadata.loc[0, 'ct_scan'])
slices = cts.shape[2]
print('Number of slices: ', slices)
    
arr = cts.get_fdata()
arr = np.rot90(np.array(arr))
arr = arr[:,:,range(80,200,20)]
arr = np.reshape(np.rollaxis(arr, 2),(arr.shape[2],arr.shape[0],arr.shape[1], 1))

fig, axes = plt.subplots(3, 6, figsize=(21,10))    

for i in range(arr.shape[0]):
    img = cv2.resize(arr[i], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
    xmax, xmin = img.max(), img.min()
    img = (img - xmin)/(xmax - xmin)
    clahe_img = clahe_enhancer(img, clahe, list(axes[:, i]))
# Out:
# Number of slices:  301

# %% [markdown]
# ## **2) Crop the ROI**

# %%
cts = nib.load(metadata.loc[0, 'ct_scan'])
slices = cts.shape[2]
print('Number of slices: ', slices)
    
arr = cts.get_fdata()
arr = np.rot90(np.array(arr))
arr = arr[:,:,range(80,200,20)]
arr = np.reshape(np.rollaxis(arr, 2),(arr.shape[2],arr.shape[0],arr.shape[1], 1))

fig, axes = plt.subplots(3, 6, figsize=(18,9))    

for i in range(arr.shape[0]):
    img = cv2.resize(arr[i], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
    xmax, xmin = img.max(), img.min()
    img = (img - xmin)/(xmax - xmin)
    _, bounds = crop_img(img, [])
    axes[0,i].imshow(img, cmap='bone')
    axes[0,i].set_title('Original CT')
    axes[0,i].set_xticks([]); axes[0,i].set_yticks([])
    
    clahe_img = clahe_enhancer(img, clahe, [])
    axes[1,i].imshow(clahe_img, cmap='bone')
    axes[1,i].set_title('Enhanced CT')
    axes[1,i].set_xticks([]); axes[1,i].set_yticks([])
    
    cropped_img = crop_(clahe_img, bounds)
    axes[2,i].imshow(cropped_img, cmap='bone')
    axes[2,i].set_title('Enhanced & cropped')
    axes[2,i].set_xticks([]); axes[2,i].set_yticks([])
# Out:
# Number of slices:  301

# %%
cts = nib.load(metadata.loc[0, 'ct_scan'])
lungs = nib.load(metadata.loc[0, 'lung_mask'])
infec = nib.load(metadata.loc[0, 'infection_mask'])
slices = cts.shape[2]
    
arr_cts = cts.get_fdata()
arr_lungs = lungs.get_fdata()
arr_infec = infec.get_fdata()

arr_cts = np.rot90(np.array(arr_cts))
arr_lungs = np.rot90(np.array(arr_lungs))
arr_infec = np.rot90(np.array(arr_infec))

arr_cts = arr_cts[:, :, range(80,200,20)]
arr_lungs = arr_lungs[:, :, range(80,200,20)]
arr_infec = arr_infec[:, :, range(80,200,20)]

arr_cts = np.reshape(np.rollaxis(arr_cts, 2), 
                     (arr_cts.shape[2],arr_cts.shape[0],arr_cts.shape[1], 1))
arr_lungs = np.reshape(np.rollaxis(arr_lungs, 2), 
                     (arr_lungs.shape[2],arr_lungs.shape[0],arr_lungs.shape[1], 1))
arr_infec = np.reshape(np.rollaxis(arr_infec, 2), 
                     (arr_infec.shape[2],arr_infec.shape[0],arr_infec.shape[1], 1))

fig, axes = plt.subplots(3, 6, figsize=(18,6))    

for i in range(arr_cts.shape[0]):
    img_ct = cv2.resize(arr_cts[i], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
    img_lungs = cv2.resize(arr_lungs[i], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
    img_infec = cv2.resize(arr_infec[i], dsize=(img_size, img_size), interpolation=cv2.INTER_AREA)
    
    xmax, xmin = img_lungs.max(), img_lungs.min()
    img_lungs = (img_lungs - xmin)/(xmax - xmin)
    cropped_lungs, bounds = crop_img(img_lungs, [])
    
    xmax, xmin = img_ct.max(), img_ct.min()
    img_ct = (img_ct - xmin)/(xmax - xmin)
    clahe_ct = clahe_enhancer(img_ct, clahe, [])
    cropped_ct = crop_(clahe_ct, bounds)
    cropped_infec = crop_(img_infec, bounds)
    
    axes[0,i].imshow(cropped_ct, cmap='bone')
    axes[0,i].set_title("CT scan")
    axes[0,i].set_xticks([]); axes[0,i].set_yticks([])
    
    axes[1,i].imshow(cropped_lungs, cmap='bone')
    axes[1,i].set_title("Lungs mask")
    axes[1,i].set_xticks([]); axes[1,i].set_yticks([])

    axes[2,i].imshow(cropped_infec, cmap='bone')
    axes[2,i].set_title("Infection mask")
    axes[2,i].set_xticks([]); axes[2,i].set_yticks([])

# %%
cts_all = []
lungs_all = []
infects_all = []
max_w, max_h = 0, 0 #max width and height

for fnum in tqdm(range(20)) : #range(metadata.shape[0])) :
    cts = nib.load(metadata.loc[fnum, 'ct_scan'])
    lungs = nib.load(metadata.loc[fnum, 'lung_mask'])
    infec = nib.load(metadata.loc[fnum, 'infection_mask'])
    
    slices = cts.shape[2]

    arr_cts = cts.get_fdata()
    arr_lungs = lungs.get_fdata()
    arr_infec = infec.get_fdata()

    arr_cts = np.rot90(np.array(arr_cts))
    arr_lungs = np.rot90(np.array(arr_lungs))
    arr_infec = np.rot90(np.array(arr_infec))

    arr_cts = arr_cts[:, :, round(slices*0.2):round(slices*0.8)]
    arr_lungs = arr_lungs[:, :, round(slices*0.2):round(slices*0.8)]
    arr_infec = arr_infec[:, :, round(slices*0.2):round(slices*0.8)]

    arr_cts = np.reshape(np.rollaxis(arr_cts, 2), 
                     (arr_cts.shape[2],arr_cts.shape[0],arr_cts.shape[1], 1))
    arr_lungs = np.reshape(np.rollaxis(arr_lungs, 2), 
                     (arr_lungs.shape[2],arr_lungs.shape[0],arr_lungs.shape[1], 1))
    arr_infec = np.reshape(np.rollaxis(arr_infec, 2), 
                     (arr_infec.shape[2],arr_infec.shape[0],arr_infec.shape[1], 1))
    
    
    
    for i in range(arr_cts.shape[0]):
        img_lungs = cv2.resize(arr_lungs[i], dsize=(img_size, img_size), 
                              interpolation=cv2.INTER_AREA)
        xmax, xmin = img_lungs.max(), img_lungs.min()
        img_lungs = (img_lungs - xmin)/(xmax - xmin)
        cropped_lungs, bounds = crop_img(img_lungs, [])
        lungs_all.append(cropped_lungs)
        
        h, w = cropped_img.shape
        max_h, max_w = max(max_h, h), max(max_w, w)

        img_ct = cv2.resize(arr_cts[i], dsize=(img_size, img_size), 
                           interpolation=cv2.INTER_AREA)
        xmax, xmin = img_ct.max(), img_ct.min()
        img_ct = (img_ct - xmin)/(xmax - xmin)
        clahe_ct = clahe_enhancer(img_ct, clahe, [])
        cropped_ct = crop_(clahe_ct, bounds)
        cts_all.append(cropped_ct)

        img_infec = cv2.resize(arr_infec[i], dsize=(img_size, img_size), 
                              interpolation=cv2.INTER_AREA)
        cropped_infec = crop_(img_infec, bounds)
        infects_all.append(cropped_infec)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning:
#
# invalid value encountered in true_divide

# %%
print(len(cts_all))
# Out:
# 2112

# %% [markdown]
# ## **3) Removing incomplete and faulty images**

# %%
#Reshape each slice and delete faulty images

pix_size = 128

del_lst = []
for i in tqdm(range(len(cts_all))) :
    try :
        cts_all[i] = cv2.resize(cts_all[i], dsize=(pix_size, pix_size), interpolation=cv2.INTER_AREA)
        cts_all[i] = np.reshape(cts_all[i], (pix_size, pix_size, 1))

        lungs_all[i] = cv2.resize(lungs_all[i], dsize=(pix_size, pix_size), interpolation=cv2.INTER_AREA)
        lungs_all[i] = np.reshape(lungs_all[i], (pix_size, pix_size, 1))

        infects_all[i] = cv2.resize(infects_all[i], dsize=(pix_size, pix_size), interpolation=cv2.INTER_AREA)
        infects_all[i] = np.reshape(infects_all[i], (pix_size, pix_size, 1))
    except :
        del_lst.append(i)
            
    
for idx in del_lst[::-1] :
    del cts_all[idx]
    del lungs_all[idx]
    del infects_all[idx]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2112.0), HTML(value='')))

# %%
print(len(cts_all))
# Out:
# 2094

# %%
def check_empty(img):
    # Count white pixels
    sought = [1,1,1]
    white  = np.count_nonzero(img==sought)
    
    if white == 0:
        return(True)

# %%
# delete empty masks

del_lst = []
for i in tqdm(range(len(infects_all))) :
    if check_empty(infects_all[i]):
        del_lst.append(i)
            
    
for idx in del_lst[::-1] :
    del cts_all[idx]
    del lungs_all[idx]
    del infects_all[idx]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2094.0), HTML(value='')))

# %%
print(len(cts_all)) # len of correct slices
# Out:
# 1243

# %%
fig, axes = plt.subplots(1, 3, figsize=(9,3))

axes[0].imshow(cts_all[250][:, :, 0],cmap = 'bone')
axes[0].set_title("Enhanced & Cropped CT")

axes[1].imshow(lungs_all[250][:, :, 0], cmap='bone')
axes[1].set_title("Lungs")

axes[2].imshow(infects_all[250][:, :, 0], cmap='bone')
axes[2].set_title("Infection");

# %% [markdown]
# ##  **Defining Covid19 CT Dataset**

# %%
class Covid19_CT_Dataset(torch.utils.data.Dataset):
    
    def __init__(self, cts, masks, transforms=None):
        self.transforms = transforms
        self.cts = cts
        self.masks = masks
        self.len = len(cts)
        
    def __getitem__(self,index):
        

        image = self.cts[index]
        target_mask = self.masks[index]
           
        
        if self.transforms is not None:
            augment = self.transforms(image=image,mask=target_mask)
            image = augment['image']
            target_mask = augment['mask']


        target_mask = ToTensor()(image=target_mask)['image']
        
        image = ToTensor()(image=image)['image']
        
        result = {
            
            'image': image,
            'mask': target_mask
                 
        }
        
        return result
    
    
    def __len__(self):
        return self.len

# %% [markdown]
# ## **Simple augmentations for train subset**

# %%
transforms = {
    'base': Compose([
                    HorizontalFlip(p=0.5),
                    VerticalFlip(p=0.2),
                    ]),    
}

# %%
dataset = Covid19_CT_Dataset(cts_all,lungs_all)

# %%
img_id = 100

fig, axes = plt.subplots(1, 2, figsize=(8,8)) 

axes[0].imshow(dataset[img_id]["image"].squeeze() , cmap = 'bone')
axes[0].set_title("Image")


axes[1].imshow(dataset[img_id]["mask"].squeeze() > 0 , cmap = 'bone')
axes[1].set_title("Ground Truth")
# Out:
# Text(0.5, 1.0, 'Ground Truth')

# %% [markdown]
# ## **U-Net baseline**

# %%
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels , in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)


    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
    
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        
    def forward(self, x):
        return self.conv(x)


class UNet(nn.Module):
    """ Full assembly of the parts to form the complete network """
    def __init__(self, n_channels = 1, n_classes = 1, bilinear=True):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        factor = 2 if bilinear else 1
        self.down4 = Down(512, 1024 // factor)
        self.up1 = Up(1024, 512 // factor, bilinear)
        self.up2 = Up(512, 256 // factor, bilinear)
        self.up3 = Up(256, 128 // factor, bilinear)
        self.up4 = Up(128, 64, bilinear)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)

        return logits

# %% [markdown]
# ## **Defining subsets for Task 1 and Task 2**

# %%
csv_file = r'../input/covid19-ct-scans/metadata.csv'
df = pd.read_csv(csv_file)
train_val_thresh = int(len(cts_all)*0.8)

cts_path = df['ct_scan'].tolist()
lungs_path = df['lung_mask'].tolist()
infects_path = df['infection_mask'].tolist()

train_cts = cts_all[:train_val_thresh]
train_lungs = lungs_all[:train_val_thresh]
train_infects = infects_all[:train_val_thresh]

val_cts = cts_all[train_val_thresh:]
val_lungs = lungs_all[train_val_thresh:]
val_infects = infects_all[train_val_thresh:]

# %%
lungs_train = Covid19_CT_Dataset(train_cts, train_lungs, transforms = transforms['base']) # for Task 1
lungs_val = Covid19_CT_Dataset(val_cts, val_lungs)

infects_train = Covid19_CT_Dataset(train_cts, train_infects, transforms = transforms['base']) # for Task 2
infects_val = Covid19_CT_Dataset(val_cts, val_infects)

# %%
lungs_train_loader = torch.utils.data.DataLoader(lungs_train, batch_size=32, shuffle=True, num_workers=2)
lungs_val_loader = torch.utils.data.DataLoader(lungs_val, batch_size=32, shuffle=False, num_workers=2)

infects_train_loader = torch.utils.data.DataLoader(infects_train, batch_size=32, shuffle=True, num_workers=2)
infects_val_loader = torch.utils.data.DataLoader(infects_val, batch_size=32, shuffle=False, num_workers=2)

# %% [markdown]
# ## **Defining runner for training**

# %%
criterion = {
    "dice": DiceLoss(),
    "iou": IoULoss(),
    "bce": nn.BCEWithLogitsLoss()
}

callbacks = [
    dl.CriterionCallback(
        input_key="mask", prefix="loss_dice", criterion_key="dice"
    ),
    dl.CriterionCallback(
        input_key="mask", prefix="loss_iou", criterion_key="iou"
    ),
    dl.CriterionCallback(
        input_key="mask", prefix="loss_bce", criterion_key="bce"
    ),
    dl.MetricAggregationCallback(
        prefix="loss",
        mode="weighted_sum",
        metrics={"loss_dice": 1.0, "loss_iou": 1.0, "loss_bce": 1.0},
    ),
    dl.DiceCallback(input_key="mask"),
    dl.IouCallback(input_key="mask"),
    dl.callbacks.WandbLogger(
            project="lungs_infs_segmentation"
        )
]

# %% [markdown]
# # **Task 1 (Lungs Segmentations)**
# ---

# %%
lungs_model = UNet().to(device)

# %%
lungs_runner = SupervisedRunner(input_key="image", input_target_key="mask", device=device)

optimizer = torch.optim.Adam(lungs_model.parameters(), lr=1e-3)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0 = 10, eta_min = 1e-6)

lungs_loaders = {
    "train": lungs_train_loader,
    "valid": lungs_val_loader,
}

# %%
lungs_runner.train(
    model = lungs_model,
    criterion = criterion,
    optimizer = optimizer,
    scheduler = scheduler,
    loaders = lungs_loaders,
    callbacks = callbacks,
    num_epochs = 30,
    main_metric = "dice", 
    minimize_metric = False,
    verbose = True,
    
)
# Out:
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/haksorus/lungs_infs_segmentation" target="_blank">https://app.wandb.ai/haksorus/lungs_infs_segmentation</a><br/>
#                 Run page: <a href="https://app.wandb.ai/haksorus/lungs_infs_segmentation/runs/u6swlcc9" target="_blank">https://app.wandb.ai/haksorus/lungs_infs_segmentation/runs/u6swlcc9</a><br/>
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: Wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# 1/30 * Epoch (train):   0% 0/32 [00:00<?, ?it/s]
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# 1/30 * Epoch (train): 100% 32/32 [00:25<00:00,  1.24it/s, dice=0.761, iou=0.614, loss=1.017, loss_bce=0.393, loss_dice=0.239, loss_iou=0.386]
# 1/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.143, iou=0.077, loss=3.015, loss_bce=1.234, loss_dice=0.857, loss_iou=0.923]
# [2022-07-25 18:02:52,451]
# 1/30 * Epoch 1 (_base): lr=0.0010 | momentum=0.9000
# 1/30 * Epoch 1 (train): dice=0.7617 | iou=0.6188 | loss=1.0292 | loss_bce=0.4096 | loss_dice=0.2383 | loss_iou=0.3812
# 1/30 * Epoch 1 (valid): dice=0.1592 | iou=0.0874 | loss=2.8647 | loss_bce=1.1112 | loss_dice=0.8408 | loss_iou=0.9126
# 2/30 * Epoch (train):   0% 0/32 [00:00<?, ?it/s]
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:942: UserWarning:
#
# To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
# 2/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.806, iou=0.675, loss=0.904, loss_bce=0.385, loss_dice=0.194, loss_iou=0.325]
# 2/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.786, iou=0.648, loss=1.026, loss_bce=0.460, loss_dice=0.214, loss_iou=0.352]
# [2022-07-25 18:03:19,577]
# 2/30 * Epoch 2 (_base): lr=0.0009 | momentum=0.9000
# 2/30 * Epoch 2 (train): dice=0.8023 | iou=0.6699 | loss=0.8999 | loss_bce=0.3721 | loss_dice=0.1977 | loss_iou=0.3301
# 2/30 * Epoch 2 (valid): dice=0.7892 | iou=0.6536 | loss=0.9411 | loss_bce=0.3838 | loss_dice=0.2108 | loss_iou=0.3464
# 3/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.837, iou=0.719, loss=0.752, loss_bce=0.308, loss_dice=0.163, loss_iou=0.281]
# 3/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.808, iou=0.678, loss=0.933, loss_bce=0.419, loss_dice=0.192, loss_iou=0.322]
# [2022-07-25 18:03:46,696]
# 3/30 * Epoch 3 (_base): lr=0.0008 | momentum=0.9000
# 3/30 * Epoch 3 (train): dice=0.8131 | iou=0.6851 | loss=0.8631 | loss_bce=0.3613 | loss_dice=0.1869 | loss_iou=0.3149
# 3/30 * Epoch 3 (valid): dice=0.7952 | iou=0.6610 | loss=0.9188 | loss_bce=0.3750 | loss_dice=0.2048 | loss_iou=0.3390
# 4/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.827, iou=0.705, loss=0.759, loss_bce=0.291, loss_dice=0.173, loss_iou=0.295]
# 4/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.763, iou=0.617, loss=0.992, loss_bce=0.373, loss_dice=0.237, loss_iou=0.383]
# [2022-07-25 18:04:13,800]
# 4/30 * Epoch 4 (_base): lr=0.0007 | momentum=0.9000
# 4/30 * Epoch 4 (train): dice=0.8177 | iou=0.6917 | loss=0.8302 | loss_bce=0.3396 | loss_dice=0.1823 | loss_iou=0.3083
# 4/30 * Epoch 4 (valid): dice=0.7556 | iou=0.6086 | loss=0.9649 | loss_bce=0.3291 | loss_dice=0.2444 | loss_iou=0.3914
# 5/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.817, iou=0.691, loss=0.833, loss_bce=0.342, loss_dice=0.183, loss_iou=0.309]
# 5/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.49it/s, dice=0.802, iou=0.669, loss=0.872, loss_bce=0.342, loss_dice=0.198, loss_iou=0.331]
# [2022-07-25 18:04:41,069]
# 5/30 * Epoch 5 (_base): lr=0.0005 | momentum=0.9000
# 5/30 * Epoch 5 (train): dice=0.8225 | iou=0.6985 | loss=0.7793 | loss_bce=0.3002 | loss_dice=0.1775 | loss_iou=0.3015
# 5/30 * Epoch 5 (valid): dice=0.8041 | iou=0.6734 | loss=0.8184 | loss_bce=0.2959 | loss_dice=0.1959 | loss_iou=0.3266
# 6/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.430, iou=0.274, loss=2.336, loss_bce=1.041, loss_dice=0.570, loss_iou=0.726]
# 6/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.67it/s, dice=0.719, iou=0.562, loss=2.352, loss_bce=1.633, loss_dice=0.281, loss_iou=0.438]
# [2022-07-25 18:05:08,157]
# 6/30 * Epoch 6 (_base): lr=0.0003 | momentum=0.9000
# 6/30 * Epoch 6 (train): dice=0.8277 | iou=0.7064 | loss=0.7398 | loss_bce=0.2740 | loss_dice=0.1723 | loss_iou=0.2936
# 6/30 * Epoch 6 (valid): dice=0.7302 | iou=0.5762 | loss=1.9865 | loss_bce=1.2929 | loss_dice=0.2698 | loss_iou=0.4238
# 7/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.838, iou=0.721, loss=0.694, loss_bce=0.253, loss_dice=0.162, loss_iou=0.279]
# 7/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.766, iou=0.621, loss=0.894, loss_bce=0.281, loss_dice=0.234, loss_iou=0.379]
# [2022-07-25 18:05:35,295]
# 7/30 * Epoch 7 (_base): lr=0.0002 | momentum=0.9000
# 7/30 * Epoch 7 (train): dice=0.8223 | iou=0.6983 | loss=0.7725 | loss_bce=0.2931 | loss_dice=0.1777 | loss_iou=0.3017
# 7/30 * Epoch 7 (valid): dice=0.7618 | iou=0.6168 | loss=0.8775 | loss_bce=0.2562 | loss_dice=0.2382 | loss_iou=0.3832
# 8/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.850, iou=0.739, loss=0.612, loss_bce=0.202, loss_dice=0.150, loss_iou=0.261]
# 8/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.799, iou=0.666, loss=0.816, loss_bce=0.281, loss_dice=0.201, loss_iou=0.334]
# [2022-07-25 18:06:02,414]
# 8/30 * Epoch 8 (_base): lr=9.640e-05 | momentum=0.9000
# 8/30 * Epoch 8 (train): dice=0.8302 | iou=0.7097 | loss=0.7086 | loss_bce=0.2484 | loss_dice=0.1698 | loss_iou=0.2903
# 8/30 * Epoch 8 (valid): dice=0.8083 | iou=0.6798 | loss=0.7598 | loss_bce=0.2478 | loss_dice=0.1917 | loss_iou=0.3202
# 9/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.811, iou=0.682, loss=0.841, loss_bce=0.335, loss_dice=0.189, loss_iou=0.318]
# 9/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.773, iou=0.630, loss=0.912, loss_bce=0.316, loss_dice=0.227, loss_iou=0.370]
# [2022-07-25 18:06:29,578]
# 9/30 * Epoch 9 (_base): lr=2.545e-05 | momentum=0.9000
# 9/30 * Epoch 9 (train): dice=0.8329 | iou=0.7137 | loss=0.6892 | loss_bce=0.2358 | loss_dice=0.1671 | loss_iou=0.2863
# 9/30 * Epoch 9 (valid): dice=0.7851 | iou=0.6481 | loss=0.8394 | loss_bce=0.2725 | loss_dice=0.2149 | loss_iou=0.3519
# 10/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.837, iou=0.719, loss=0.676, loss_bce=0.232, loss_dice=0.163, loss_iou=0.281]
# 10/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.67it/s, dice=0.787, iou=0.648, loss=0.867, loss_bce=0.302, loss_dice=0.213, loss_iou=0.352]
# [2022-07-25 18:06:56,666]
# 10/30 * Epoch 10 (_base): lr=0.0010 | momentum=0.9000
# 10/30 * Epoch 10 (train): dice=0.8337 | iou=0.7148 | loss=0.6868 | loss_bce=0.2352 | loss_dice=0.1663 | loss_iou=0.2852
# 10/30 * Epoch 10 (valid): dice=0.8037 | iou=0.6736 | loss=0.7839 | loss_bce=0.2612 | loss_dice=0.1963 | loss_iou=0.3264
# 11/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.840, iou=0.724, loss=0.686, loss_bce=0.250, loss_dice=0.160, loss_iou=0.276]
# 11/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.60it/s, dice=0.811, iou=0.682, loss=0.854, loss_bce=0.347, loss_dice=0.189, loss_iou=0.318]
# [2022-07-25 18:07:23,788]
# 11/30 * Epoch 11 (_base): lr=0.0010 | momentum=0.9000
# 11/30 * Epoch 11 (train): dice=0.8294 | iou=0.7086 | loss=0.7309 | loss_bce=0.2689 | loss_dice=0.1706 | loss_iou=0.2914
# 11/30 * Epoch 11 (valid): dice=0.8204 | iou=0.6971 | loss=0.7835 | loss_bce=0.3009 | loss_dice=0.1796 | loss_iou=0.3029
# 12/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.686, iou=0.522, loss=1.123, loss_bce=0.330, loss_dice=0.314, loss_iou=0.478]
# 12/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.57it/s, dice=0.730, iou=0.575, loss=3.339, loss_bce=2.643, loss_dice=0.270, loss_iou=0.425]
# [2022-07-25 18:07:50,923]
# 12/30 * Epoch 12 (_base): lr=0.0009 | momentum=0.9000
# 12/30 * Epoch 12 (train): dice=0.8319 | iou=0.7123 | loss=0.7088 | loss_bce=0.2530 | loss_dice=0.1681 | loss_iou=0.2877
# 12/30 * Epoch 12 (valid): dice=0.7441 | iou=0.5936 | loss=2.6891 | loss_bce=2.0268 | loss_dice=0.2559 | loss_iou=0.4064
# 13/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.842, iou=0.726, loss=0.655, loss_bce=0.223, loss_dice=0.158, loss_iou=0.274]
# 13/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.61it/s, dice=0.804, iou=0.672, loss=0.884, loss_bce=0.360, loss_dice=0.196, loss_iou=0.328]
# [2022-07-25 18:08:18,136]
# 13/30 * Epoch 13 (_base): lr=0.0008 | momentum=0.9000
# 13/30 * Epoch 13 (train): dice=0.8268 | iou=0.7048 | loss=0.7432 | loss_bce=0.2748 | loss_dice=0.1732 | loss_iou=0.2952
# 13/30 * Epoch 13 (valid): dice=0.8085 | iou=0.6805 | loss=0.8119 | loss_bce=0.3009 | loss_dice=0.1915 | loss_iou=0.3195
# 14/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.844, iou=0.730, loss=0.650, loss_bce=0.225, loss_dice=0.156, loss_iou=0.270]
# 14/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.830, iou=0.709, loss=0.782, loss_bce=0.322, loss_dice=0.170, loss_iou=0.291]
# [2022-07-25 18:08:45,263]
# 14/30 * Epoch 14 (_base): lr=0.0007 | momentum=0.9000
# 14/30 * Epoch 14 (train): dice=0.8331 | iou=0.7140 | loss=0.7019 | loss_bce=0.2489 | loss_dice=0.1669 | loss_iou=0.2860
# 14/30 * Epoch 14 (valid): dice=0.8350 | iou=0.7177 | loss=0.7378 | loss_bce=0.2904 | loss_dice=0.1650 | loss_iou=0.2823
# 15/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.845, iou=0.732, loss=0.643, loss_bce=0.221, loss_dice=0.155, loss_iou=0.268]
# 15/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.56it/s, dice=0.791, iou=0.655, loss=0.858, loss_bce=0.304, loss_dice=0.209, loss_iou=0.345]
# [2022-07-25 18:09:12,439]
# 15/30 * Epoch 15 (_base): lr=0.0005 | momentum=0.9000
# 15/30 * Epoch 15 (train): dice=0.8363 | iou=0.7187 | loss=0.6714 | loss_bce=0.2264 | loss_dice=0.1637 | loss_iou=0.2813
# 15/30 * Epoch 15 (valid): dice=0.8034 | iou=0.6732 | loss=0.7901 | loss_bce=0.2667 | loss_dice=0.1966 | loss_iou=0.3268
# 16/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.837, iou=0.719, loss=0.630, loss_bce=0.186, loss_dice=0.163, loss_iou=0.281]
# 16/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.805, iou=0.674, loss=0.796, loss_bce=0.276, loss_dice=0.195, loss_iou=0.326]
# [2022-07-25 18:09:39,537]
# 16/30 * Epoch 16 (_base): lr=0.0003 | momentum=0.9000
# 16/30 * Epoch 16 (train): dice=0.8378 | iou=0.7209 | loss=0.6632 | loss_bce=0.2219 | loss_dice=0.1622 | loss_iou=0.2791
# 16/30 * Epoch 16 (valid): dice=0.8141 | iou=0.6883 | loss=0.7352 | loss_bce=0.2376 | loss_dice=0.1859 | loss_iou=0.3117
# 17/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.783, iou=0.643, loss=0.933, loss_bce=0.359, loss_dice=0.217, loss_iou=0.357]
# 17/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.826, iou=0.703, loss=0.708, loss_bce=0.237, loss_dice=0.174, loss_iou=0.297]
# [2022-07-25 18:10:06,640]
# 17/30 * Epoch 17 (_base): lr=0.0002 | momentum=0.9000
# 17/30 * Epoch 17 (train): dice=0.8393 | iou=0.7231 | loss=0.6514 | loss_bce=0.2137 | loss_dice=0.1607 | loss_iou=0.2769
# 17/30 * Epoch 17 (valid): dice=0.8293 | iou=0.7097 | loss=0.6763 | loss_bce=0.2153 | loss_dice=0.1707 | loss_iou=0.2903
# 18/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.837, iou=0.720, loss=0.684, loss_bce=0.241, loss_dice=0.163, loss_iou=0.280]
# 18/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.45it/s, dice=0.817, iou=0.691, loss=0.767, loss_bce=0.274, loss_dice=0.183, loss_iou=0.309]
# [2022-07-25 18:10:33,959]
# 18/30 * Epoch 18 (_base): lr=9.640e-05 | momentum=0.9000
# 18/30 * Epoch 18 (train): dice=0.8374 | iou=0.7202 | loss=0.6631 | loss_bce=0.2207 | loss_dice=0.1626 | loss_iou=0.2798
# 18/30 * Epoch 18 (valid): dice=0.8208 | iou=0.6977 | loss=0.7180 | loss_bce=0.2366 | loss_dice=0.1792 | loss_iou=0.3023
# 19/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.847, iou=0.734, loss=0.630, loss_bce=0.210, loss_dice=0.153, loss_iou=0.266]
# 19/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.820, iou=0.695, loss=0.735, loss_bce=0.251, loss_dice=0.180, loss_iou=0.305]
# [2022-07-25 18:11:01,036]
# 19/30 * Epoch 19 (_base): lr=2.545e-05 | momentum=0.9000
# 19/30 * Epoch 19 (train): dice=0.8395 | iou=0.7234 | loss=0.6479 | loss_bce=0.2108 | loss_dice=0.1605 | loss_iou=0.2766
# 19/30 * Epoch 19 (valid): dice=0.8236 | iou=0.7015 | loss=0.6982 | loss_bce=0.2232 | loss_dice=0.1764 | loss_iou=0.2985
# 20/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.841, iou=0.726, loss=0.661, loss_bce=0.227, loss_dice=0.159, loss_iou=0.274]
# 20/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.819, iou=0.693, loss=0.750, loss_bce=0.262, loss_dice=0.181, loss_iou=0.307]
# [2022-07-25 18:11:28,166]
# 20/30 * Epoch 20 (_base): lr=0.0010 | momentum=0.9000
# 20/30 * Epoch 20 (train): dice=0.8400 | iou=0.7242 | loss=0.6447 | loss_bce=0.2089 | loss_dice=0.1600 | loss_iou=0.2758
# 20/30 * Epoch 20 (valid): dice=0.8232 | iou=0.7010 | loss=0.7037 | loss_bce=0.2278 | loss_dice=0.1768 | loss_iou=0.2990
# 21/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.826, iou=0.703, loss=0.727, loss_bce=0.256, loss_dice=0.174, loss_iou=0.297]
# 21/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.68it/s, dice=0.724, iou=0.568, loss=1.055, loss_bce=0.348, loss_dice=0.276, loss_iou=0.432]
# [2022-07-25 18:11:55,284]
# 21/30 * Epoch 21 (_base): lr=0.0010 | momentum=0.9000
# 21/30 * Epoch 21 (train): dice=0.8354 | iou=0.7173 | loss=0.6795 | loss_bce=0.2322 | loss_dice=0.1646 | loss_iou=0.2827
# 21/30 * Epoch 21 (valid): dice=0.7597 | iou=0.6144 | loss=0.9223 | loss_bce=0.2964 | loss_dice=0.2403 | loss_iou=0.3856
# 22/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.835, iou=0.717, loss=0.693, loss_bce=0.246, loss_dice=0.165, loss_iou=0.283]
# 22/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.790, iou=0.653, loss=0.843, loss_bce=0.285, loss_dice=0.210, loss_iou=0.347]
# [2022-07-25 18:12:22,407]
# 22/30 * Epoch 22 (_base): lr=0.0009 | momentum=0.9000
# 22/30 * Epoch 22 (train): dice=0.8364 | iou=0.7188 | loss=0.6760 | loss_bce=0.2313 | loss_dice=0.1636 | loss_iou=0.2812
# 22/30 * Epoch 22 (valid): dice=0.8061 | iou=0.6777 | loss=0.7561 | loss_bce=0.2400 | loss_dice=0.1939 | loss_iou=0.3223
# 23/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.818, iou=0.692, loss=0.833, loss_bce=0.343, loss_dice=0.182, loss_iou=0.308]
# 23/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.718, iou=0.560, loss=1.086, loss_bce=0.364, loss_dice=0.282, loss_iou=0.440]
# [2022-07-25 18:12:49,517]
# 23/30 * Epoch 23 (_base): lr=0.0008 | momentum=0.9000
# 23/30 * Epoch 23 (train): dice=0.8387 | iou=0.7222 | loss=0.6553 | loss_bce=0.2161 | loss_dice=0.1613 | loss_iou=0.2778
# 23/30 * Epoch 23 (valid): dice=0.7460 | iou=0.5962 | loss=0.9777 | loss_bce=0.3199 | loss_dice=0.2540 | loss_iou=0.4038
# 24/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.840, iou=0.725, loss=0.670, loss_bce=0.235, loss_dice=0.160, loss_iou=0.275]
# 24/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.824, iou=0.701, loss=0.721, loss_bce=0.246, loss_dice=0.176, loss_iou=0.299]
# [2022-07-25 18:13:16,622]
# 24/30 * Epoch 24 (_base): lr=0.0007 | momentum=0.9000
# 24/30 * Epoch 24 (train): dice=0.8357 | iou=0.7178 | loss=0.6815 | loss_bce=0.2350 | loss_dice=0.1643 | loss_iou=0.2822
# 24/30 * Epoch 24 (valid): dice=0.8274 | iou=0.7070 | loss=0.6892 | loss_bce=0.2236 | loss_dice=0.1726 | loss_iou=0.2930
# 25/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.808, iou=0.678, loss=0.730, loss_bce=0.215, loss_dice=0.192, loss_iou=0.322]
# 25/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.53it/s, dice=0.811, iou=0.682, loss=0.761, loss_bce=0.254, loss_dice=0.189, loss_iou=0.318]
# [2022-07-25 18:13:43,802]
# 25/30 * Epoch 25 (_base): lr=0.0005 | momentum=0.9000
# 25/30 * Epoch 25 (train): dice=0.8395 | iou=0.7234 | loss=0.6502 | loss_bce=0.2131 | loss_dice=0.1605 | loss_iou=0.2766
# 25/30 * Epoch 25 (valid): dice=0.8152 | iou=0.6896 | loss=0.7307 | loss_bce=0.2355 | loss_dice=0.1848 | loss_iou=0.3104
# 26/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.799, iou=0.666, loss=0.788, loss_bce=0.253, loss_dice=0.201, loss_iou=0.334]
# 26/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.53it/s, dice=0.819, iou=0.694, loss=0.729, loss_bce=0.242, loss_dice=0.181, loss_iou=0.306]
# [2022-07-25 18:14:11,023]
# 26/30 * Epoch 26 (_base): lr=0.0003 | momentum=0.9000
# 26/30 * Epoch 26 (train): dice=0.8404 | iou=0.7248 | loss=0.6433 | loss_bce=0.2085 | loss_dice=0.1596 | loss_iou=0.2752
# 26/30 * Epoch 26 (valid): dice=0.8221 | iou=0.6992 | loss=0.7020 | loss_bce=0.2232 | loss_dice=0.1779 | loss_iou=0.3008
# 27/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.838, iou=0.721, loss=0.665, loss_bce=0.223, loss_dice=0.162, loss_iou=0.279]
# 27/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.829, iou=0.708, loss=0.700, loss_bce=0.238, loss_dice=0.171, loss_iou=0.292]
# [2022-07-25 18:14:38,111]
# 27/30 * Epoch 27 (_base): lr=0.0002 | momentum=0.9000
# 27/30 * Epoch 27 (train): dice=0.8397 | iou=0.7238 | loss=0.6487 | loss_bce=0.2122 | loss_dice=0.1603 | loss_iou=0.2762
# 27/30 * Epoch 27 (valid): dice=0.8303 | iou=0.7113 | loss=0.6745 | loss_bce=0.2162 | loss_dice=0.1697 | loss_iou=0.2887
# 28/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.842, iou=0.727, loss=0.683, loss_bce=0.252, loss_dice=0.158, loss_iou=0.273]
# 28/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.823, iou=0.700, loss=0.722, loss_bce=0.245, loss_dice=0.177, loss_iou=0.300]
# [2022-07-25 18:15:05,187]
# 28/30 * Epoch 28 (_base): lr=9.640e-05 | momentum=0.9000
# 28/30 * Epoch 28 (train): dice=0.8412 | iou=0.7259 | loss=0.6373 | loss_bce=0.2045 | loss_dice=0.1588 | loss_iou=0.2741
# 28/30 * Epoch 28 (valid): dice=0.8275 | iou=0.7073 | loss=0.6865 | loss_bce=0.2213 | loss_dice=0.1725 | loss_iou=0.2927
# 29/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.832, iou=0.713, loss=0.725, loss_bce=0.270, loss_dice=0.168, loss_iou=0.287]
# 29/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.822, iou=0.698, loss=0.723, loss_bce=0.243, loss_dice=0.178, loss_iou=0.302]
# [2022-07-25 18:15:32,282]
# 29/30 * Epoch 29 (_base): lr=2.545e-05 | momentum=0.9000
# 29/30 * Epoch 29 (train): dice=0.8411 | iou=0.7258 | loss=0.6389 | loss_bce=0.2059 | loss_dice=0.1589 | loss_iou=0.2742
# 29/30 * Epoch 29 (valid): dice=0.8253 | iou=0.7041 | loss=0.6932 | loss_bce=0.2225 | loss_dice=0.1747 | loss_iou=0.2959
# 30/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.813, iou=0.685, loss=0.745, loss_bce=0.243, loss_dice=0.187, loss_iou=0.315]
# 30/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.826, iou=0.704, loss=0.706, loss_bce=0.236, loss_dice=0.174, loss_iou=0.296]
# [2022-07-25 18:15:59,395]
# 30/30 * Epoch 30 (_base): lr=0.0010 | momentum=0.9000
# 30/30 * Epoch 30 (train): dice=0.8416 | iou=0.7265 | loss=0.6348 | loss_bce=0.2029 | loss_dice=0.1584 | loss_iou=0.2735
# 30/30 * Epoch 30 (valid): dice=0.8300 | iou=0.7107 | loss=0.6769 | loss_bce=0.2176 | loss_dice=0.1700 | loss_iou=0.2893
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory

# %% [markdown]
# ## **Checking model inference**

# %%
visualize_mask(lungs_model, lungs_val)

# %% [markdown]
# # **Task 2 (Infection Segmentation)**
# ---

# %%
torch.cuda.empty_cache()

# %%
infects_model = UNet().to(device)

# %%
infects_runner = SupervisedRunner(input_key="image", input_target_key="mask", device=device)

optimizer = torch.optim.Adam(infects_model.parameters(), lr=1e-3)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0 = 10, eta_min = 1e-6)

infects_loaders = {
    "train": infects_train_loader,
    "valid": infects_val_loader,
}

# %%
infects_runner.train(
    model = infects_model,
    criterion = criterion,
    optimizer = optimizer,
    scheduler = scheduler,
    loaders = infects_loaders,
    callbacks = callbacks,
    num_epochs = 30,
    main_metric = "dice", 
    minimize_metric = False,
    verbose = True,
)
# Out:
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/haksorus/lungs_infs_segmentation" target="_blank">https://app.wandb.ai/haksorus/lungs_infs_segmentation</a><br/>
#                 Run page: <a href="https://app.wandb.ai/haksorus/lungs_infs_segmentation/runs/1qn3p5zs" target="_blank">https://app.wandb.ai/haksorus/lungs_infs_segmentation/runs/1qn3p5zs</a><br/>
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: Wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# 1/30 * Epoch (train):   0% 0/32 [00:00<?, ?it/s]
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# 1/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.115, iou=0.061, loss=2.156, loss_bce=0.332, loss_dice=0.885, loss_iou=0.939]
# 1/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.54it/s, dice=0.099, iou=0.052, loss=2.233, loss_bce=0.384, loss_dice=0.901, loss_iou=0.948]
# [2022-07-25 18:16:32,282]
# 1/30 * Epoch 1 (_base): lr=0.0010 | momentum=0.9000
# 1/30 * Epoch 1 (train): dice=0.1793 | iou=0.0995 | loss=2.1547 | loss_bce=0.4335 | loss_dice=0.8207 | loss_iou=0.9005
# 1/30 * Epoch 1 (valid): dice=0.1051 | iou=0.0558 | loss=2.2244 | loss_bce=0.3854 | loss_dice=0.8949 | loss_iou=0.9442
# 2/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.086, iou=0.045, loss=2.165, loss_bce=0.295, loss_dice=0.914, loss_iou=0.955]
# 2/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.49it/s, dice=0.294, iou=0.172, loss=1.988, loss_bce=0.455, loss_dice=0.706, loss_iou=0.828]
# [2022-07-25 18:16:59,567]
# 2/30 * Epoch 2 (_base): lr=0.0009 | momentum=0.9000
# 2/30 * Epoch 2 (train): dice=0.2905 | iou=0.1708 | loss=1.7654 | loss_bce=0.2267 | loss_dice=0.7095 | loss_iou=0.8292
# 2/30 * Epoch 2 (valid): dice=0.2976 | iou=0.1785 | loss=2.1511 | loss_bce=0.6272 | loss_dice=0.7024 | loss_iou=0.8215
# 3/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.428, iou=0.273, loss=1.443, loss_bce=0.144, loss_dice=0.572, loss_iou=0.727]
# 3/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.62it/s, dice=0.322, iou=0.192, loss=1.689, loss_bce=0.203, loss_dice=0.678, loss_iou=0.808]
# [2022-07-25 18:17:26,733]
# 3/30 * Epoch 3 (_base): lr=0.0008 | momentum=0.9000
# 3/30 * Epoch 3 (train): dice=0.4068 | iou=0.2568 | loss=1.4828 | loss_bce=0.1464 | loss_dice=0.5932 | loss_iou=0.7432
# 3/30 * Epoch 3 (valid): dice=0.3656 | iou=0.2299 | loss=1.6277 | loss_bce=0.2232 | loss_dice=0.6344 | loss_iou=0.7701
# 4/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.446, iou=0.287, loss=1.403, loss_bce=0.135, loss_dice=0.554, loss_iou=0.713]
# 4/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.55it/s, dice=0.515, iou=0.346, loss=1.295, loss_bce=0.157, loss_dice=0.485, loss_iou=0.654]
# [2022-07-25 18:17:54,004]
# 4/30 * Epoch 4 (_base): lr=0.0007 | momentum=0.9000
# 4/30 * Epoch 4 (train): dice=0.5222 | iou=0.3547 | loss=1.2278 | loss_bce=0.1047 | loss_dice=0.4778 | loss_iou=0.6453
# 4/30 * Epoch 4 (valid): dice=0.4707 | iou=0.3149 | loss=1.4014 | loss_bce=0.1870 | loss_dice=0.5293 | loss_iou=0.6851
# 5/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.663, iou=0.496, loss=0.924, loss_bce=0.082, loss_dice=0.337, loss_iou=0.504]
# 5/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.62it/s, dice=0.626, iou=0.455, loss=1.051, loss_bce=0.131, loss_dice=0.374, loss_iou=0.545]
# [2022-07-25 18:18:21,182]
# 5/30 * Epoch 5 (_base): lr=0.0005 | momentum=0.9000
# 5/30 * Epoch 5 (train): dice=0.6063 | iou=0.4369 | loss=1.0446 | loss_bce=0.0879 | loss_dice=0.3937 | loss_iou=0.5631
# 5/30 * Epoch 5 (valid): dice=0.5897 | iou=0.4252 | loss=1.1470 | loss_bce=0.1619 | loss_dice=0.4103 | loss_iou=0.5748
# 6/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.262, iou=0.151, loss=1.862, loss_bce=0.275, loss_dice=0.738, loss_iou=0.849]
# 6/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.62it/s, dice=0.504, iou=0.337, loss=1.521, loss_bce=0.362, loss_dice=0.496, loss_iou=0.663]
# [2022-07-25 18:18:48,359]
# 6/30 * Epoch 6 (_base): lr=0.0003 | momentum=0.9000
# 6/30 * Epoch 6 (train): dice=0.6801 | iou=0.5165 | loss=0.8769 | loss_bce=0.0735 | loss_dice=0.3199 | loss_iou=0.4835
# 6/30 * Epoch 6 (valid): dice=0.4754 | iou=0.3171 | loss=1.8406 | loss_bce=0.6332 | loss_dice=0.5246 | loss_iou=0.6829
# 7/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.654, iou=0.485, loss=1.043, loss_bce=0.182, loss_dice=0.346, loss_iou=0.515]
# 7/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.649, iou=0.481, loss=0.993, loss_bce=0.123, loss_dice=0.351, loss_iou=0.519]
# [2022-07-25 18:19:15,523]
# 7/30 * Epoch 7 (_base): lr=0.0002 | momentum=0.9000
# 7/30 * Epoch 7 (train): dice=0.7013 | iou=0.5412 | loss=0.8282 | loss_bce=0.0707 | loss_dice=0.2987 | loss_iou=0.4588
# 7/30 * Epoch 7 (valid): dice=0.5656 | iou=0.4008 | loss=1.1851 | loss_bce=0.1516 | loss_dice=0.4344 | loss_iou=0.5992
# 8/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.803, iou=0.671, loss=0.579, loss_bce=0.054, loss_dice=0.197, loss_iou=0.329]
# 8/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.45it/s, dice=0.695, iou=0.533, loss=0.873, loss_bce=0.100, loss_dice=0.305, loss_iou=0.467]
# [2022-07-25 18:19:42,825]
# 8/30 * Epoch 8 (_base): lr=9.640e-05 | momentum=0.9000
# 8/30 * Epoch 8 (train): dice=0.7252 | iou=0.5709 | loss=0.7701 | loss_bce=0.0662 | loss_dice=0.2748 | loss_iou=0.4291
# 8/30 * Epoch 8 (valid): dice=0.6371 | iou=0.4765 | loss=1.0167 | loss_bce=0.1303 | loss_dice=0.3629 | loss_iou=0.5235
# 9/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.329, iou=0.197, loss=1.667, loss_bce=0.194, loss_dice=0.671, loss_iou=0.803]
# 9/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.61it/s, dice=0.666, iou=0.500, loss=0.988, loss_bce=0.154, loss_dice=0.334, loss_iou=0.500]
# [2022-07-25 18:20:09,973]
# 9/30 * Epoch 9 (_base): lr=2.545e-05 | momentum=0.9000
# 9/30 * Epoch 9 (train): dice=0.7436 | iou=0.5929 | loss=0.7269 | loss_bce=0.0634 | loss_dice=0.2564 | loss_iou=0.4071
# 9/30 * Epoch 9 (valid): dice=0.6635 | iou=0.5036 | loss=0.9796 | loss_bce=0.1467 | loss_dice=0.3365 | loss_iou=0.4964
# 10/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.738, iou=0.584, loss=0.776, loss_bce=0.098, loss_dice=0.262, loss_iou=0.416]
# 10/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.698, iou=0.536, loss=0.889, loss_bce=0.123, loss_dice=0.302, loss_iou=0.464]
# [2022-07-25 18:20:37,155]
# 10/30 * Epoch 10 (_base): lr=0.0010 | momentum=0.9000
# 10/30 * Epoch 10 (train): dice=0.7512 | iou=0.6023 | loss=0.7072 | loss_bce=0.0607 | loss_dice=0.2488 | loss_iou=0.3977
# 10/30 * Epoch 10 (valid): dice=0.6774 | iou=0.5201 | loss=0.9375 | loss_bce=0.1349 | loss_dice=0.3226 | loss_iou=0.4799
# 11/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.577, iou=0.406, loss=1.093, loss_bce=0.076, loss_dice=0.423, loss_iou=0.594]
# 11/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.634, iou=0.464, loss=1.029, loss_bce=0.127, loss_dice=0.366, loss_iou=0.536]
# [2022-07-25 18:21:04,318]
# 11/30 * Epoch 11 (_base): lr=0.0010 | momentum=0.9000
# 11/30 * Epoch 11 (train): dice=0.7317 | iou=0.5779 | loss=0.7636 | loss_bce=0.0732 | loss_dice=0.2683 | loss_iou=0.4221
# 11/30 * Epoch 11 (valid): dice=0.4546 | iou=0.3003 | loss=1.4475 | loss_bce=0.2024 | loss_dice=0.5454 | loss_iou=0.6997
# 12/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.425, iou=0.270, loss=1.480, loss_bce=0.174, loss_dice=0.575, loss_iou=0.730]
# 12/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.61it/s, dice=0.235, iou=0.133, loss=3.716, loss_bce=2.085, loss_dice=0.765, loss_iou=0.867]
# [2022-07-25 18:21:31,513]
# 12/30 * Epoch 12 (_base): lr=0.0009 | momentum=0.9000
# 12/30 * Epoch 12 (train): dice=0.7584 | iou=0.6123 | loss=0.6976 | loss_bce=0.0683 | loss_dice=0.2416 | loss_iou=0.3877
# 12/30 * Epoch 12 (valid): dice=0.2939 | iou=0.1782 | loss=3.3151 | loss_bce=1.7872 | loss_dice=0.7061 | loss_iou=0.8218
# 13/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.788, iou=0.651, loss=0.615, loss_bce=0.054, loss_dice=0.212, loss_iou=0.349]
# 13/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.748, iou=0.598, loss=0.758, loss_bce=0.104, loss_dice=0.252, loss_iou=0.402]
# [2022-07-25 18:21:58,668]
# 13/30 * Epoch 13 (_base): lr=0.0008 | momentum=0.9000
# 13/30 * Epoch 13 (train): dice=0.7666 | iou=0.6226 | loss=0.6812 | loss_bce=0.0704 | loss_dice=0.2334 | loss_iou=0.3774
# 13/30 * Epoch 13 (valid): dice=0.7063 | iou=0.5566 | loss=0.8584 | loss_bce=0.1213 | loss_dice=0.2937 | loss_iou=0.4434
# 14/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.623, iou=0.452, loss=0.993, loss_bce=0.069, loss_dice=0.377, loss_iou=0.548]
# 14/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.55it/s, dice=0.749, iou=0.599, loss=0.752, loss_bce=0.101, loss_dice=0.251, loss_iou=0.401]
# [2022-07-25 18:22:25,861]
# 14/30 * Epoch 14 (_base): lr=0.0007 | momentum=0.9000
# 14/30 * Epoch 14 (train): dice=0.7911 | iou=0.6552 | loss=0.6167 | loss_bce=0.0630 | loss_dice=0.2089 | loss_iou=0.3448
# 14/30 * Epoch 14 (valid): dice=0.6412 | iou=0.4821 | loss=1.0292 | loss_bce=0.1525 | loss_dice=0.3588 | loss_iou=0.5179
# 15/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.758, iou=0.611, loss=0.697, loss_bce=0.066, loss_dice=0.242, loss_iou=0.389]
# 15/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.631, iou=0.461, loss=1.075, loss_bce=0.167, loss_dice=0.369, loss_iou=0.539]
# [2022-07-25 18:22:52,939]
# 15/30 * Epoch 15 (_base): lr=0.0005 | momentum=0.9000
# 15/30 * Epoch 15 (train): dice=0.7801 | iou=0.6404 | loss=0.6491 | loss_bce=0.0697 | loss_dice=0.2199 | loss_iou=0.3596
# 15/30 * Epoch 15 (valid): dice=0.6428 | iou=0.4768 | loss=1.0825 | loss_bce=0.2021 | loss_dice=0.3572 | loss_iou=0.5232
# 16/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.774, iou=0.632, loss=0.635, loss_bce=0.041, loss_dice=0.226, loss_iou=0.368]
# 16/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.655, iou=0.487, loss=1.017, loss_bce=0.160, loss_dice=0.345, loss_iou=0.513]
# [2022-07-25 18:23:20,041]
# 16/30 * Epoch 16 (_base): lr=0.0003 | momentum=0.9000
# 16/30 * Epoch 16 (train): dice=0.8088 | iou=0.6794 | loss=0.5705 | loss_bce=0.0587 | loss_dice=0.1912 | loss_iou=0.3206
# 16/30 * Epoch 16 (valid): dice=0.6463 | iou=0.4850 | loss=1.0579 | loss_bce=0.1891 | loss_dice=0.3537 | loss_iou=0.5150
# 17/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.492, iou=0.326, loss=1.299, loss_bce=0.117, loss_dice=0.508, loss_iou=0.674]
# 17/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.741, iou=0.589, loss=0.776, loss_bce=0.107, loss_dice=0.259, loss_iou=0.411]
# [2022-07-25 18:23:47,140]
# 17/30 * Epoch 17 (_base): lr=0.0002 | momentum=0.9000
# 17/30 * Epoch 17 (train): dice=0.8038 | iou=0.6725 | loss=0.5866 | loss_bce=0.0628 | loss_dice=0.1962 | loss_iou=0.3275
# 17/30 * Epoch 17 (valid): dice=0.7166 | iou=0.5659 | loss=0.8466 | loss_bce=0.1291 | loss_dice=0.2834 | loss_iou=0.4341
# 18/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.267, iou=0.154, loss=1.740, loss_bce=0.162, loss_dice=0.733, loss_iou=0.846]
# 18/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.57it/s, dice=0.755, iou=0.606, loss=0.752, loss_bce=0.113, loss_dice=0.245, loss_iou=0.394]
# [2022-07-25 18:24:14,309]
# 18/30 * Epoch 18 (_base): lr=9.640e-05 | momentum=0.9000
# 18/30 * Epoch 18 (train): dice=0.8163 | iou=0.6905 | loss=0.5503 | loss_bce=0.0571 | loss_dice=0.1837 | loss_iou=0.3095
# 18/30 * Epoch 18 (valid): dice=0.7248 | iou=0.5747 | loss=0.8431 | loss_bce=0.1426 | loss_dice=0.2752 | loss_iou=0.4253
# 19/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.794, iou=0.659, loss=0.674, loss_bce=0.127, loss_dice=0.206, loss_iou=0.341]
# 19/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.63it/s, dice=0.770, iou=0.625, loss=0.702, loss_bce=0.096, loss_dice=0.230, loss_iou=0.375]
# [2022-07-25 18:24:41,415]
# 19/30 * Epoch 19 (_base): lr=2.545e-05 | momentum=0.9000
# 19/30 * Epoch 19 (train): dice=0.8192 | iou=0.6943 | loss=0.5430 | loss_bce=0.0564 | loss_dice=0.1808 | loss_iou=0.3057
# 19/30 * Epoch 19 (valid): dice=0.7319 | iou=0.5834 | loss=0.8121 | loss_bce=0.1274 | loss_dice=0.2681 | loss_iou=0.4166
# 20/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.790, iou=0.653, loss=0.751, loss_bce=0.194, loss_dice=0.210, loss_iou=0.347]
# 20/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.64it/s, dice=0.785, iou=0.646, loss=0.656, loss_bce=0.087, loss_dice=0.215, loss_iou=0.354]
# [2022-07-25 18:25:08,508]
# 20/30 * Epoch 20 (_base): lr=0.0010 | momentum=0.9000
# 20/30 * Epoch 20 (train): dice=0.8253 | iou=0.7029 | loss=0.5259 | loss_bce=0.0541 | loss_dice=0.1747 | loss_iou=0.2971
# 20/30 * Epoch 20 (valid): dice=0.7323 | iou=0.5852 | loss=0.8007 | loss_bce=0.1182 | loss_dice=0.2677 | loss_iou=0.4148
# 21/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.793, iou=0.657, loss=0.601, loss_bce=0.052, loss_dice=0.207, loss_iou=0.343]
# 21/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.57it/s, dice=0.813, iou=0.684, loss=0.578, loss_bce=0.075, loss_dice=0.187, loss_iou=0.316]
# [2022-07-25 18:25:35,652]
# 21/30 * Epoch 21 (_base): lr=0.0010 | momentum=0.9000
# 21/30 * Epoch 21 (train): dice=0.8102 | iou=0.6818 | loss=0.5691 | loss_bce=0.0611 | loss_dice=0.1898 | loss_iou=0.3182
# 21/30 * Epoch 21 (valid): dice=0.7346 | iou=0.5878 | loss=0.7946 | loss_bce=0.1170 | loss_dice=0.2654 | loss_iou=0.4122
# 22/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.635, iou=0.465, loss=1.002, loss_bce=0.103, loss_dice=0.365, loss_iou=0.535]
# 22/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.723, iou=0.566, loss=0.839, loss_bce=0.128, loss_dice=0.277, loss_iou=0.434]
# [2022-07-25 18:26:02,809]
# 22/30 * Epoch 22 (_base): lr=0.0009 | momentum=0.9000
# 22/30 * Epoch 22 (train): dice=0.8113 | iou=0.6830 | loss=0.5679 | loss_bce=0.0621 | loss_dice=0.1887 | loss_iou=0.3170
# 22/30 * Epoch 22 (valid): dice=0.7023 | iou=0.5473 | loss=0.9129 | loss_bce=0.1625 | loss_dice=0.2977 | loss_iou=0.4527
# 23/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.746, iou=0.594, loss=0.765, loss_bce=0.104, loss_dice=0.254, loss_iou=0.406]
# 23/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.745, iou=0.594, loss=0.778, loss_bce=0.116, loss_dice=0.255, loss_iou=0.406]
# [2022-07-25 18:26:29,923]
# 23/30 * Epoch 23 (_base): lr=0.0008 | momentum=0.9000
# 23/30 * Epoch 23 (train): dice=0.8063 | iou=0.6763 | loss=0.5815 | loss_bce=0.0642 | loss_dice=0.1937 | loss_iou=0.3237
# 23/30 * Epoch 23 (valid): dice=0.6979 | iou=0.5456 | loss=0.8961 | loss_bce=0.1395 | loss_dice=0.3021 | loss_iou=0.4544
# 24/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.807, iou=0.677, loss=0.646, loss_bce=0.130, loss_dice=0.193, loss_iou=0.323]
# 24/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.66it/s, dice=0.486, iou=0.321, loss=1.587, loss_bce=0.394, loss_dice=0.514, loss_iou=0.679]
# [2022-07-25 18:26:57,028]
# 24/30 * Epoch 24 (_base): lr=0.0007 | momentum=0.9000
# 24/30 * Epoch 24 (train): dice=0.8002 | iou=0.6678 | loss=0.5993 | loss_bce=0.0673 | loss_dice=0.1998 | loss_iou=0.3322
# 24/30 * Epoch 24 (valid): dice=0.5294 | iou=0.3693 | loss=1.4849 | loss_bce=0.3836 | loss_dice=0.4706 | loss_iou=0.6307
# 25/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.331, iou=0.198, loss=1.575, loss_bce=0.104, loss_dice=0.669, loss_iou=0.802]
# 25/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.709, iou=0.550, loss=0.876, loss_bce=0.135, loss_dice=0.291, loss_iou=0.450]
# [2022-07-25 18:27:24,162]
# 25/30 * Epoch 25 (_base): lr=0.0005 | momentum=0.9000
# 25/30 * Epoch 25 (train): dice=0.8228 | iou=0.6997 | loss=0.5353 | loss_bce=0.0578 | loss_dice=0.1772 | loss_iou=0.3003
# 25/30 * Epoch 25 (valid): dice=0.7219 | iou=0.5712 | loss=0.8450 | loss_bce=0.1382 | loss_dice=0.2781 | loss_iou=0.4288
# 26/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.645, iou=0.476, loss=1.174, loss_bce=0.296, loss_dice=0.355, loss_iou=0.524]
# 26/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.610, iou=0.439, loss=1.164, loss_bce=0.213, loss_dice=0.390, loss_iou=0.561]
# [2022-07-25 18:27:51,278]
# 26/30 * Epoch 26 (_base): lr=0.0003 | momentum=0.9000
# 26/30 * Epoch 26 (train): dice=0.8219 | iou=0.6981 | loss=0.5400 | loss_bce=0.0600 | loss_dice=0.1781 | loss_iou=0.3019
# 26/30 * Epoch 26 (valid): dice=0.6494 | iou=0.4877 | loss=1.0821 | loss_bce=0.2192 | loss_dice=0.3506 | loss_iou=0.5123
# 27/30 * Epoch (train): 100% 32/32 [00:25<00:00,  1.28it/s, dice=0.787, iou=0.649, loss=0.652, loss_bce=0.089, loss_dice=0.213, loss_iou=0.351]
# 27/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.34it/s, dice=0.772, iou=0.628, loss=0.710, loss_bce=0.110, loss_dice=0.228, loss_iou=0.372]
# [2022-07-25 18:28:18,718]
# 27/30 * Epoch 27 (_base): lr=0.0002 | momentum=0.9000
# 27/30 * Epoch 27 (train): dice=0.8155 | iou=0.6894 | loss=0.5563 | loss_bce=0.0612 | loss_dice=0.1845 | loss_iou=0.3106
# 27/30 * Epoch 27 (valid): dice=0.7525 | iou=0.6090 | loss=0.7639 | loss_bce=0.1254 | loss_dice=0.2475 | loss_iou=0.3910
# 28/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.561, iou=0.389, loss=1.149, loss_bce=0.099, loss_dice=0.439, loss_iou=0.611]
# 28/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.741, iou=0.588, loss=0.793, loss_bce=0.122, loss_dice=0.259, loss_iou=0.412]
# [2022-07-25 18:28:45,815]
# 28/30 * Epoch 28 (_base): lr=9.640e-05 | momentum=0.9000
# 28/30 * Epoch 28 (train): dice=0.8342 | iou=0.7159 | loss=0.5042 | loss_bce=0.0543 | loss_dice=0.1658 | loss_iou=0.2841
# 28/30 * Epoch 28 (valid): dice=0.7393 | iou=0.5927 | loss=0.7976 | loss_bce=0.1295 | loss_dice=0.2607 | loss_iou=0.4073
# 29/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.28it/s, dice=0.882, iou=0.788, loss=0.371, loss_bce=0.041, loss_dice=0.118, loss_iou=0.212]
# 29/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.51it/s, dice=0.746, iou=0.594, loss=0.779, loss_bce=0.119, loss_dice=0.254, loss_iou=0.406]
# [2022-07-25 18:29:13,057]
# 29/30 * Epoch 29 (_base): lr=2.545e-05 | momentum=0.9000
# 29/30 * Epoch 29 (train): dice=0.8359 | iou=0.7185 | loss=0.4988 | loss_bce=0.0532 | loss_dice=0.1641 | loss_iou=0.2815
# 29/30 * Epoch 29 (valid): dice=0.7397 | iou=0.5931 | loss=0.7970 | loss_bce=0.1298 | loss_dice=0.2603 | loss_iou=0.4069
# 30/30 * Epoch (train): 100% 32/32 [00:24<00:00,  1.29it/s, dice=0.800, iou=0.666, loss=0.582, loss_bce=0.048, loss_dice=0.200, loss_iou=0.334]
# 30/30 * Epoch (valid): 100% 8/8 [00:02<00:00,  3.65it/s, dice=0.757, iou=0.609, loss=0.748, loss_bce=0.114, loss_dice=0.243, loss_iou=0.391]
# [2022-07-25 18:29:40,161]
# 30/30 * Epoch 30 (_base): lr=0.0010 | momentum=0.9000
# 30/30 * Epoch 30 (train): dice=0.8415 | iou=0.7268 | loss=0.4829 | loss_bce=0.0513 | loss_dice=0.1585 | loss_iou=0.2732
# 30/30 * Epoch 30 (valid): dice=0.7469 | iou=0.6018 | loss=0.7789 | loss_bce=0.1276 | loss_dice=0.2531 | loss_iou=0.3982
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path None/wandb/ wasn't writable, using system temp directory

# %% [markdown]
# ## **Checking model inference**

# %%
visualize_mask(infects_model, infects_val, threshold = True, threshold_value = 0.9)

# %% [markdown]
# ![image.png](attachment:0a0e1975-26f3-48ca-945c-89248aba81dd.png)
#
# ![image.png](attachment:0595548e-d15a-49b1-b3c8-cbc5c5b3430b.png)
